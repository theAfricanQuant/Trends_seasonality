# %%
# we import the libraries
import pandas as pd
import numpy as np

# %%
# we mport the csv files of the datasets we want to use

#A
AUDUSD = pd.read_csv('AUDUSD1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
AUDJPY = pd.read_csv('AUDJPY1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])

#E
EURAUD = pd.read_csv('EURAUD1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
EURCAD = pd.read_csv('EURCAD1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
EURCHF = pd.read_csv('EURCHF1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
EURGBP = pd.read_csv('EURGBP1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
EURJPY = pd.read_csv('EURJPY1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
EURUSD = pd.read_csv('EURUSD1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])

#G
GBPAUD = pd.read_csv('GBPUSD1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
GBPCAD = pd.read_csv('GBPCAD1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
GBPJPY = pd.read_csv('GBPJPY1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
GBPUSD = pd.read_csv('GBPUSD1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])

#U
USDCAD = pd.read_csv('USDCAD1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
USDCHF = pd.read_csv('USDCHF1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
USDJPY = pd.read_csv('USDJPY1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])

# %%
# delete the "Time", "Open", "High", "Low" and "Volume" Columns from each dataset as we don't need them
AUDUSD.drop(AUDUSD.loc[:, ["Time", "Open", "High", "Low", "Volume"]], inplace=True, axis=1)
AUDJPY.drop(AUDJPY.loc[:, ["Time", "Open", "High", "Low", "Volume"]], inplace=True, axis=1)

EURAUD.drop(EURAUD.loc[:, ["Time", "Open", "High", "Low", "Volume"]], inplace=True, axis=1)
EURCAD.drop(EURCAD.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)
EURCHF.drop(EURCHF.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)
EURGBP.drop(EURGBP.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)
EURJPY.drop(EURJPY.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)
EURUSD.drop(EURUSD.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)

GBPAUD.drop(GBPAUD.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)
GBPCAD.drop(GBPCAD.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)
GBPJPY.drop(GBPJPY.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)
GBPUSD.drop(GBPUSD.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)

USDCAD.drop(USDCAD.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)
USDCHF.drop(USDCHF.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)
USDJPY.drop(USDJPY.loc[:, ["Time", "Open", "High", "Low",  "Volume"]], inplace=True, axis=1)

# %%
# we need to convert the date column from a string to a datetime format

AUDUSD['Date'] = pd.to_datetime(AUDUSD['Date'])
AUDJPY['Date'] = pd.to_datetime(AUDJPY['Date'])

EURAUD['Date'] = pd.to_datetime(EURAUD['Date'])
EURCAD['Date'] = pd.to_datetime(EURCAD['Date'])
EURCHF['Date'] = pd.to_datetime(EURCHF['Date'])
EURGBP['Date'] = pd.to_datetime(EURGBP['Date'])
EURJPY['Date'] = pd.to_datetime(EURJPY['Date'])
EURUSD['Date'] = pd.to_datetime(EURUSD['Date'])

GBPAUD['Date'] = pd.to_datetime(GBPAUD['Date'])
GBPCAD['Date'] = pd.to_datetime(GBPCAD['Date'])
GBPJPY['Date'] = pd.to_datetime(GBPJPY['Date'])
GBPUSD['Date'] = pd.to_datetime(GBPUSD['Date'])

USDCAD['Date'] = pd.to_datetime(USDCAD['Date'])
USDCHF['Date'] = pd.to_datetime(USDCHF['Date'])
USDJPY['Date'] = pd.to_datetime(USDJPY['Date'])

# %%
USDJPY
# Out:
#             Date    Close   Week_day  Week_year   Returns USDJPY_Direction
# 0     1971-01-04  357.730     Monday          1       NaN             Bear
# 1     1971-01-05  357.810    Tuesday          1  0.000224             Bull
# 2     1971-01-06  357.860  Wednesday          1  0.000140             Bull
# 3     1971-01-07  357.870   Thursday          1  0.000028             Bull
# 4     1971-01-08  357.820     Friday          1 -0.000140             Bear
# 5     1971-01-11  357.950     Monday          2  0.000363             Bull
# 6     1971-01-12  358.060    Tuesday          2  0.000307             Bull
# 7     1971-01-13  358.440  Wednesday          2  0.001061             Bull
# 8     1971-01-14  358.400   Thursday          2 -0.000112             Bear
# 9     1971-01-15  358.400     Friday          2  0.000000             Bear
# 10    1971-01-18  358.290     Monday          3 -0.000307             Bear
# ...

# %%
# We are going to add all the columns that we need in this step
AUDUSD['Week_day'] = AUDUSD.Date.dt.weekday_name
AUDUSD['Week_year'] = AUDUSD.Date.dt.weekofyear
AUDUSD['Returns'] = (AUDUSD.Close/AUDUSD.Close.shift(1)) - 1
AUDUSD['AUDUSD_Direction'] = np.where(AUDUSD.Returns >0,'Bull', 'Bear')

# %%
AUDJPY['Week_day'] = AUDJPY.Date.dt.weekday_name
AUDJPY['Week_year'] = AUDJPY.Date.dt.weekofyear
AUDJPY['Returns'] = (AUDJPY.Close/AUDJPY.Close.shift(1)) - 1
AUDJPY['AUDJPY_Direction'] = np.where(AUDJPY.Returns >0,'Bull', 'Bear')

# %%
EURAUD['Week_day'] = EURAUD.Date.dt.weekday_name
EURAUD['Week_year'] = EURAUD.Date.dt.weekofyear
EURAUD['Returns'] = (EURAUD.Close/EURAUD.Close.shift(1)) - 1
EURAUD['EURAUD_Direction'] = np.where(EURAUD.Returns >0,'Bull', 'Bear')

# %%
EURCAD['Week_day'] = EURCAD.Date.dt.weekday_name
EURCAD['Week_year'] = EURCAD.Date.dt.weekofyear
EURCAD['Returns'] = (EURCAD.Close/EURCAD.Close.shift(1)) - 1
EURCAD['EURCAD_Direction'] = np.where(EURCAD.Returns >0,'Bull', 'Bear')

# %%
EURCHF['Week_day'] = EURCHF.Date.dt.weekday_name
EURCHF['Week_year'] = EURCHF.Date.dt.weekofyear
EURCHF['Returns'] = (EURCHF.Close/EURCHF.Close.shift(1)) - 1
EURCHF['EURCHF_Direction'] = np.where(EURCHF.Returns >0,'Bull', 'Bear')

# %%
EURGBP['Week_day'] = EURGBP.Date.dt.weekday_name
EURGBP['Week_year'] = EURGBP.Date.dt.weekofyear
EURGBP['Returns'] = (EURGBP.Close/EURGBP.Close.shift(1)) - 1
EURGBP['EURGBP_Direction'] = np.where(EURGBP.Returns >0,'Bull', 'Bear')

# %%
EURJPY['Week_day'] = EURJPY.Date.dt.weekday_name
EURJPY['Week_year'] = EURJPY.Date.dt.weekofyear
EURJPY['Returns'] = (EURJPY.Close/EURJPY.Close.shift(1)) - 1
EURJPY['EURJPY_Direction'] = np.where(EURJPY.Returns >0,'Bull', 'Bear')

# %%
EURUSD['Week_day'] = EURUSD.Date.dt.weekday_name
EURUSD['Week_year'] = EURUSD.Date.dt.weekofyear
EURUSD['Returns'] = (EURUSD.Close/EURUSD.Close.shift(1)) - 1
EURUSD['EURUSD_Direction'] = np.where(EURUSD.Returns >0,'Bull', 'Bear')

# %%
GBPAUD['Week_day'] = GBPAUD.Date.dt.weekday_name
GBPAUD['Week_year'] = GBPAUD.Date.dt.weekofyear
GBPAUD['Returns'] = (GBPAUD.Close/GBPAUD.Close.shift(1)) - 1
GBPAUD['GBPAUD_Direction'] = np.where(GBPAUD.Returns >0,'Bull', 'Bear')

# %%
GBPCAD['Week_day'] = GBPCAD.Date.dt.weekday_name
GBPCAD['Week_year'] = GBPCAD.Date.dt.weekofyear
GBPCAD['Returns'] = (GBPCAD.Close/GBPCAD.Close.shift(1)) - 1
GBPCAD['GBPCAD_Direction'] = np.where(GBPCAD.Returns >0,'Bull', 'Bear')

# %%
GBPJPY['Week_day'] = GBPJPY.Date.dt.weekday_name
GBPJPY['Week_year'] = GBPJPY.Date.dt.weekofyear
GBPJPY['Returns'] = (GBPJPY.Close/GBPJPY.Close.shift(1)) - 1
GBPJPY['GBPJPY_Direction'] = np.where(GBPJPY.Returns >0,'Bull', 'Bear')

# %%
GBPUSD['Week_day'] = GBPUSD.Date.dt.weekday_name
GBPUSD['Week_year'] = GBPUSD.Date.dt.weekofyear
GBPUSD['Returns'] = (GBPUSD.Close/GBPUSD.Close.shift(1)) - 1
GBPUSD['GBPUSD_Direction'] = np.where(GBPUSD.Returns >0,'Bull', 'Bear')

# %%
USDCAD['Week_day'] = USDCAD.Date.dt.weekday_name
USDCAD['Week_year'] = USDCAD.Date.dt.weekofyear
USDCAD['Returns'] = (USDCAD.Close/USDCAD.Close.shift(1)) - 1
USDCAD['USDCAD_Direction'] = np.where(USDCAD.Returns >0,'Bull', 'Bear')

# %%
USDCHF['Week_day'] = USDCHF.Date.dt.weekday_name
USDCHF['Week_year'] = USDCHF.Date.dt.weekofyear
USDCHF['Returns'] = (USDCHF.Close/USDCHF.Close.shift(1)) - 1
USDCHF['USDCHF_Direction'] = np.where(USDCHF.Returns >0,'Bull', 'Bear')

# %%
USDJPY['Week_day'] = USDJPY.Date.dt.weekday_name
USDJPY['Week_year'] =USDJPY.Date.dt.weekofyear
USDJPY['Returns'] = (USDJPY.Close/USDJPY.Close.shift(1)) - 1
USDJPY['USDJPY_Direction'] = np.where(USDJPY.Returns >0,'Bull', 'Bear')

# %% [markdown]
# ##### Choose a week

# %%
week = 39

# %%
#Time to calculate the Seasonality Trends
present_AUDUSD = AUDUSD.loc[AUDUSD['Week_year']== week,]
bulls_AUDUSD = present_AUDUSD.loc[present_AUDUSD['AUDUSD_Direction'] == 'Bull',:]
bears_AUDUSD = present_AUDUSD.loc[present_AUDUSD['AUDUSD_Direction'] == 'Bear',:]

# %%
op_Monbulls = bulls_AUDUSD.loc[bulls_AUDUSD['Week_day'] == 'Monday', :]
op_Tuebulls = bulls_AUDUSD.loc[bulls_AUDUSD['Week_day'] == 'Tuesday', :]
op_Wedbulls = bulls_AUDUSD.loc[bulls_AUDUSD['Week_day'] == 'Wednesday', :]
op_Thubulls = bulls_AUDUSD.loc[bulls_AUDUSD['Week_day'] == 'Thursday', :]
op_Fribulls = bulls_AUDUSD.loc[bulls_AUDUSD['Week_day'] == 'Friday', :]

# %%
op_Monbulls
# Out:
#            Date    Close Week_day  Week_year   Returns AUDUSD_Direction
# 608  1995-09-25  0.75130   Monday         39  0.006430             Bull
# 855  1996-09-23  0.79260   Monday         39  0.000631             Bull
# 1102 1997-09-22  0.72100   Monday         39  0.004178             Bull
# 1600 1999-09-27  0.65150   Monday         39  0.001383             Bull
# 1860 2000-09-25  0.54770   Monday         39  0.006801             Bull
# 2119 2001-09-24  0.49300   Monday         39  0.016914             Bull
# 2639 2003-09-22  0.67780   Monday         39  0.006983             Bull
# 2899 2004-09-20  0.70030   Monday         39  0.003583             Bull
# 3424 2006-09-25  0.75390   Monday         39  0.003461             Bull
# 3683 2007-09-24  0.86780   Monday         39  0.001154             Bull
# 3941 2008-09-22  0.84350   Monday         39  0.011633             Bull
# 4462 2010-09-27  0.96029   Monday         39  0.001366             Bull
# ...

# %%
op_Monbears = bears_AUDUSD.loc[bears_AUDUSD['Week_day'] == 'Monday', :]
op_Tuebears = bears_AUDUSD.loc[bears_AUDUSD['Week_day'] == 'Tuesday', :]
op_Wedbears = bears_AUDUSD.loc[bears_AUDUSD['Week_day'] == 'Wednesday', :]
op_Thubears = bears_AUDUSD.loc[bears_AUDUSD['Week_day'] == 'Thursday', :]
op_Fribears = bears_AUDUSD.loc[bears_AUDUSD['Week_day'] == 'Friday', :]

# %%
mon_bullConfidence =len(op_Monbulls)/(len(op_Monbulls) + len(op_Monbears))
mon_bearConfidence = len(op_Monbears)/(len(op_Monbears) + len(op_Monbulls))

# %%
tue_bullConfidence =len(op_Tuebulls)/(len(op_Tuebulls) + len(op_Tuebears))
tue_bearConfidence = len(op_Tuebears)/(len(op_Tuebears) + len(op_Tuebulls))

# %%
wed_bullConfidence =len(op_Wedbulls)/(len(op_Wedbulls) + len(op_Wedbears))
wed_bearConfidence = len(op_Wedbears)/(len(op_Wedbears) + len(op_Wedbulls))

# %%
thu_bullConfidence =len(op_Thubulls)/(len(op_Thubulls) + len(op_Thubears))
thu_bearConfidence = len(op_Thubears)/(len(op_Thubears) + len(op_Thubulls))

# %%
fri_bullConfidence =len(op_Fribulls)/(len(op_Fribulls) + len(op_Fribears))
fri_bearConfidence = len(op_Fribears)/(len(op_Fribears) + len(op_Fribulls))

# %%
AU = pd.DataFrame({'Direction':['Bull', 'Bear'], 
                  'Monday':[mon_bullConfidence, mon_bearConfidence], 
                  'Tuesday':[tue_bullConfidence, tue_bearConfidence],
                  'Wednesday':[wed_bullConfidence,wed_bearConfidence],
                  'Thursday':[thu_bullConfidence,thu_bearConfidence],
                   'Friday':[fri_bullConfidence,fri_bearConfidence]},
                   columns=['Direction','Monday','Tuesday', 'Wednesday','Thursday',  'Friday'],
                   ).set_index('Direction')
AU
# Out:
#              Monday   Tuesday  Wednesday  Thursday  Friday
# Direction
# Bull       0.576923  0.384615       0.52       0.6    0.52
# Bear       0.423077  0.615385       0.48       0.4    0.48
